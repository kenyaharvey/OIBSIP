# %% [markdown]
# # Data Quality Report - Before Cleaning
#
# This section evaluates the dataset before cleaning to identify:
# - Missing values
# - Duplicate records
# - Incorrect data types
# - Invalid values
# - Potential outliers

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %% [markdown]
# ## Missing Values
#
# The dataset was checked for missing values. Columns with missing values require a cleaning strategy based on the business meaning of the column.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate Records
#
# The dataset contains X duplicate rows. These records will be removed because duplicate transactions can distort analysis.

# %%
df.dtypes
# Out:
# Transaction ID      str
# Item                str
# Quantity            str
# Price Per Unit      str
# Total Spent         str
# Payment Method      str
# Location            str
# Transaction Date    str
# dtype: object

# %%
df["Transaction Date"].isnull().sum()
# Out:
# np.int64(159)

# %%
df = df.dropna(subset=["Transaction Date"])

# %% [markdown]
# ### Transaction Date
#
# 159 records were missing transaction dates. These rows were removed because transaction dates are required for time-based analysis, and the missing values could not be reliably inferred.

# %%
df["Quantity"].isnull().sum()
# Out:
# np.int64(138)

# %%
import pandas as pd

# Use the dataframe already defined in this notebook.
# If it is not defined, try to load a CSV from the project folder.
if "df" not in globals():
	try:
		df = pd.read_csv("data.csv")
	except FileNotFoundError:
		try:
			df = pd.read_csv("transactions.csv")
		except FileNotFoundError:
			# Fallback so the notebook does not crash if the data file is not available yet.
			df = pd.DataFrame({"Quantity": []})

if not isinstance(df, pd.DataFrame):
	raise ValueError("The variable 'df' is not a pandas DataFrame. Load the dataset before converting 'Quantity'.")

df["Quantity"] = pd.to_numeric(df["Quantity"], errors="coerce")
quantity_median = df["Quantity"].median()

print(quantity_median)
# Out:
# nan

# %%
quantity_median = df["Quantity"].median()

quantity_median
# Out:
# nan

# %%
df["Quantity"].unique()
# Out:
# array([], dtype=float64)

# %%
print(df.shape)
# Out:
# (0, 1)

# %%
print(df.columns)
# Out:
# Index(['Quantity'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Quantity  0 non-null      float64
# dtypes: float64(1)
# memory usage: 132.0 bytes

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Quantity]
# Index: []

# %%
df["Quantity"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["Quantity"] = pd.to_numeric(
    df["Quantity"],
    errors="coerce"
)
