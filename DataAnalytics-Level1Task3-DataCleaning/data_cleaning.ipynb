# %% [markdown]
# # Data Quality Report - Before Cleaning
#
# This section evaluates the dataset before cleaning to identify:
# - Missing values
# - Duplicate records
# - Incorrect data types
# - Invalid values
# - Potential outliers

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %% [markdown]
# ## Missing Values
#
# The dataset was checked for missing values. Columns with missing values require a cleaning strategy based on the business meaning of the column.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate Records
#
# The dataset contains X duplicate rows. These records will be removed because duplicate transactions can distort analysis.

# %%
df.dtypes
# Out:
# Transaction ID      str
# Item                str
# Quantity            str
# Price Per Unit      str
# Total Spent         str
# Payment Method      str
# Location            str
# Transaction Date    str
# dtype: object

# %%
df["Transaction Date"].isnull().sum()
# Out:
# np.int64(159)

# %%
df = df.dropna(subset=["Transaction Date"])

# %% [markdown]
# ### Transaction Date
#
# 159 records were missing transaction dates. These rows were removed because transaction dates are required for time-based analysis, and the missing values could not be reliably inferred.

# %%
df["Quantity"].isnull().sum()
# Out:
# np.int64(138)

# %%
quantity_median = df["Quantity"].median()

quantity_median
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 quantity_median = df["Quantity"].median()
#       2
#       3 quantity_median
#
# File /opt/anaconda3/envs/northstar/lib/python3.12/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/northstar/lib/python3.12/site-packages/pandas/core/series.py:8196, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    8117 @deprecate_nonkeyword_arguments(
#    8118     Pandas4Warning, allowed_args=["self"], name="median"
# ...

# %%
df["Quantity"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["Quantity"] = pd.to_numeric(
    df["Quantity"],
    errors="coerce"
)
